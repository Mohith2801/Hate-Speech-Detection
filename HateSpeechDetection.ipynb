# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\narra\OneDrive\Desktop\projects\Data Science\Hate speech detection\twitter_data.csv')
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet
# ...

# %%
dataset['labels']=dataset['class'].map({0:"Hate speech detected", 1:"Offensive Language Detected", 3:"No hate and offensive speech"})
dataset
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0               0      3            0                   0        3      2
# 1               1      3            0                   3        0      1
# 2               2      3            0                   3        0      1
# 3               3      3            0                   2        1      1
# 4               4      6            0                   6        0      1
# ...           ...    ...          ...                 ...      ...    ...
# 24778       25291      3            0                   2        1      1
# 24779       25292      3            0                   1        2      2
# 24780       25294      3            0                   3        0      1
# 24781       25295      6            0                   6        0      1
# 24782       25296      3            0                   0        3      2
#
#                                                    tweet  \
# ...

# %%
ds=dataset[['tweet','labels']]
ds
# Out:
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                             labels
# 0                              NaN
# 1      Offensive Language Detected
# 2      Offensive Language Detected
# 3      Offensive Language Detected
# 4      Offensive Language Detected
# ...                            ...
# ...

# %%
import re
import nltk
import string

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\narra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopword=set(stopwords.words("english"))

# %%
stemmer=nltk.SnowballStemmer("english")

# %%
def clean_data(text):
  text=str(text).lower()
  text=re.sub('https?://\S+|www\.\S+','',text)
  text=re.sub('\[.*?\]','',text)
  text=re.sub('<.*?>+','',text)
  text=re.sub('[%s]' %re.escape(string.punctuation),'',text)
  text=re.sub('\n','',text)
  text=re.sub('\w*\d\w*','',text)
  text=[word for word in text.split(' ') if word not in stopword]
  text=" ".join(text)
  text=[stemmer.stem(word) for word in text.split(' ')]
  text=" ".join(text)
  return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:4: SyntaxWarning: invalid escape sequence '\['
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\S'
# <>:4: SyntaxWarning: invalid escape sequence '\['
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\narra\AppData\Local\Temp\ipykernel_8156\3929844327.py:3: SyntaxWarning: invalid escape sequence '\S'
#   text=re.sub('https?://\S+|www\.\S+','',text)
# C:\Users\narra\AppData\Local\Temp\ipykernel_8156\3929844327.py:4: SyntaxWarning: invalid escape sequence '\['
#   text=re.sub('\[.*?\]','',text)
# C:\Users\narra\AppData\Local\Temp\ipykernel_8156\3929844327.py:8: SyntaxWarning: invalid escape sequence '\w'
#   text=re.sub('\w*\d\w*','',text)

# %%
ds['tweet']=ds['tweet'].apply(clean_data)
# Out:
# C:\Users\narra\AppData\Local\Temp\ipykernel_8156\2911424452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds['tweet']=ds['tweet'].apply(clean_data)

# %%
ds
# Out:
#                                                    tweet  \
# 0       rt mayasolov woman shouldnt complain clean ho...
# 1       rt  boy dat coldtyga dwn bad cuffin dat hoe  ...
# 2       rt urkindofbrand dawg rt  ever fuck bitch sta...
# 3                 rt cganderson vivabas look like tranni
# 4       rt shenikarobert shit hear might true might f...
# ...                                                  ...
# 24778  yous muthafin lie   coreyemanuel right tl tras...
# 24779  youv gone broke wrong heart babi drove redneck...
# 24780  young buck wanna eat dat nigguh like aint fuck...
# 24781                     youu got wild bitch tellin lie
# 24782  ruffl  ntac eileen dahlia  beauti color combin...
#
#                             labels
# 0                              NaN
# 1      Offensive Language Detected
# 2      Offensive Language Detected
# 3      Offensive Language Detected
# 4      Offensive Language Detected
# ...                            ...
# ...

# %%
ds.isnull().sum()
# Out:
# tweet        0
# labels    4163
# dtype: int64

# %%
ds=ds.dropna()

# %%
x=np.array(ds['tweet'])
y=np.array(ds['labels'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %%
cv=CountVectorizer()
x=cv.fit_transform(x)

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf= DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
test_data='you are poor'
ds=cv.transform([test_data]).toarray()
print(clf.predict(ds))
# Out:
# ['Hate speech detected']

# %%
import pickle

# Save the CountVectorizer
with open("cv.pkl", "wb") as f:
    pickle.dump(cv, f)

# Save the trained classifier
with open("clf.pkl", "wb") as f:
    pickle.dump(clf, f)
